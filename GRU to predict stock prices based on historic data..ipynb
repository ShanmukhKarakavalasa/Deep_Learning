# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout

# Load the data
df = pd.read_csv('stock_prices.csv')

# Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(df['Close'].values.reshape(-1, 1))

# Create the training data
prediction_days = 30
x_train = []
y_train = []
for i in range(prediction_days, len(scaled_data)):
    x_train.append(scaled_data[i-prediction_days:i, 0])
    y_train.append(scaled_data[i, 0])
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# Build the model
model = Sequential()
model.add(GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(GRU(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x_train, y_train, epochs=50, batch_size=32)

# Make predictions
x_test = scaled_data[-prediction_days:]
x_test = np.reshape(x_test, (1, x_test.shape[0], 1))
predicted_price = model.predict(x_test)
predicted_price = scaler.inverse_transform(predicted_price)

print("Predicted price:", predicted_price)
# Out:
# Epoch 1/50
# 55/55 [==============================] - 16s 72ms/step - loss: 0.0129
# Epoch 2/50
# 55/55 [==============================] - 4s 74ms/step - loss: 0.0021
# Epoch 3/50
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0019
# Epoch 4/50
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0017
# Epoch 5/50
# 55/55 [==============================] - 3s 63ms/step - loss: 0.0016
# Epoch 6/50
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0016
# Epoch 7/50
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0014
# Epoch 8/50
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0021
# Epoch 9/50
# 55/55 [==============================] - 4s 70ms/step - loss: 0.0012
# Epoch 10/50
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0012
# Epoch 11/50
# 55/55 [==============================] - 4s 66ms/step - loss: 0.0011
# Epoch 12/50
# 55/55 [==============================] - 3s 56ms/step - loss: 0.0012
# Epoch 13/50
# 55/55 [==============================] - 3s 56ms/step - loss: 0.0012
# Epoch 14/50
# 55/55 [==============================] - 4s 64ms/step - loss: 0.0017
# Epoch 15/50
# 55/55 [==============================] - 4s 67ms/step - loss: 0.0012
# Epoch 16/50
# 55/55 [==============================] - 3s 63ms/step - loss: 0.0012
# Epoch 17/50
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0012
# Epoch 18/50
# 55/55 [==============================] - 4s 71ms/step - loss: 9.5251e-04
# Epoch 19/50
# 55/55 [==============================] - 4s 70ms/step - loss: 9.1347e-04
# Epoch 20/50
# 55/55 [==============================] - 4s 75ms/step - loss: 0.0010
# Epoch 21/50
# 55/55 [==============================] - 4s 74ms/step - loss: 9.3269e-04
# Epoch 22/50
# 55/55 [==============================] - 4s 72ms/step - loss: 0.0010
# Epoch 23/50
# 55/55 [==============================] - 4s 74ms/step - loss: 8.8250e-04
# Epoch 24/50
# 55/55 [==============================] - 4s 72ms/step - loss: 0.0010
# Epoch 25/50
# 55/55 [==============================] - 4s 70ms/step - loss: 9.7827e-04
# Epoch 26/50
# 55/55 [==============================] - 4s 69ms/step - loss: 8.6851e-04
# Epoch 27/50
# 55/55 [==============================] - 4s 73ms/step - loss: 0.0011
# Epoch 28/50
# 55/55 [==============================] - 4s 72ms/step - loss: 9.5123e-04
# Epoch 29/50
# 55/55 [==============================] - 3s 60ms/step - loss: 9.0672e-04
# Epoch 30/50
# 55/55 [==============================] - 4s 71ms/step - loss: 8.6097e-04
# Epoch 31/50
# 55/55 [==============================] - 4s 71ms/step - loss: 9.4105e-04
# Epoch 32/50
# 55/55 [==============================] - 4s 69ms/step - loss: 9.2317e-04
# Epoch 33/50
# 55/55 [==============================] - 4s 71ms/step - loss: 9.0214e-04
# Epoch 34/50
# 55/55 [==============================] - 4s 66ms/step - loss: 8.7912e-04
# Epoch 35/50
# 55/55 [==============================] - 4s 72ms/step - loss: 0.0010
# Epoch 36/50
# 55/55 [==============================] - 4s 66ms/step - loss: 0.0012
# Epoch 37/50
# 55/55 [==============================] - 4s 69ms/step - loss: 9.4729e-04
# Epoch 38/50
# 55/55 [==============================] - 4s 65ms/step - loss: 8.4973e-04
# Epoch 39/50
# 55/55 [==============================] - 4s 67ms/step - loss: 8.0311e-04
# Epoch 40/50
# 55/55 [==============================] - 4s 68ms/step - loss: 8.9230e-04
# Epoch 41/50
# 55/55 [==============================] - 4s 66ms/step - loss: 7.1631e-04
# Epoch 42/50
# 55/55 [==============================] - 4s 70ms/step - loss: 8.8490e-04
# Epoch 43/50
# 55/55 [==============================] - 4s 69ms/step - loss: 8.9018e-04
# Epoch 44/50
# 55/55 [==============================] - 4s 71ms/step - loss: 8.6341e-04
# Epoch 45/50
# 55/55 [==============================] - 4s 74ms/step - loss: 0.0012
# Epoch 46/50
# 55/55 [==============================] - 4s 73ms/step - loss: 7.8062e-04
# Epoch 47/50
# 55/55 [==============================] - 4s 74ms/step - loss: 8.2968e-04
# Epoch 48/50
# 55/55 [==============================] - 4s 73ms/step - loss: 8.1132e-04
# Epoch 49/50
# 55/55 [==============================] - 4s 73ms/step - loss: 8.5361e-04
# Epoch 50/50
# 55/55 [==============================] - 4s 72ms/step - loss: 8.6196e-04
# 1/1 [==============================] - 2s 2s/step
# Predicted price: [[178.2224]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26980\1959594878.py in <module>
#      48
#      49 print("Predicted price:", predicted_price)
# ---> 50 print(y_test)
#
# NameError: name 'y_test' is not defined
